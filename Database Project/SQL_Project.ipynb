# %%
import sqlite3

# Function to connect to the database
def connect_to_database(database_name):
    conn = sqlite3.connect(database_name)
    return conn

# Function to execute a query and fetch results
def execute_query(conn, query):
    cursor = conn.cursor()
    cursor.execute(query)
    rows = cursor.fetchall()
    return rows

# %%
# Function to print the count of rows in each table
def print_table_counts(conn):
    tables = ["Smartphones", "Brands"]
    for table in tables:
        query = f"SELECT COUNT(*) FROM {table};"
        result = execute_query(conn, query)
        print(f"Number of rows in {table}: {result[0][0]}")

# %%
# Function to print a sample of 3 rows from each table
def print_sample_rows(conn):
    tables = ["Smartphones", "Brands"]
    for table in tables:
        query = f"SELECT * FROM {table} LIMIT 3;"
        result = execute_query(conn, query)
        print(f"Sample rows from {table}:")
        for row in result:
            print(row)
        print()

# %%
# Function to perform a join query
def perform_join(conn):
    query = """
    SELECT s.*, b.Brand_Name
    FROM Smartphones AS s
    INNER JOIN Brands AS b ON Brand_ID = b.Brand_ID;
    """
    result = execute_query(conn, query)
    print("Join result:")
    for row in result:
        print(row)

# %%
# Main function
def main():
    database_name = "C:\\Users\\Home Easy\\Desktop\\My_database"
    conn = connect_to_database(database_name)

    # Print count of rows in each table
    print_table_counts(conn)
    print()

    # Print sample of 3 rows from each table
    print_sample_rows(conn)
    print()

    # Perform join
    perform_join(conn)

    # Close connection
    conn.close()

if __name__ == "__main__":
    main()
# Out:
# Number of rows in Smartphones: 23
# Number of rows in Brands: 7
#
# Sample rows from Smartphones:
# (1, 'Realme C55 8/256GB Sunshower Libre', 'C55', 8, 256, 'Yellow', 231.6)
# (2, 'Samsung Galaxy M23 5G 4/128GB Azul Libre', 'Galaxy M23', 4, 128, 'Blue', 279.0)
# (3, 'Motorola Moto G13 4/128GB Azul Lavanda Libre', 'Moto G13', 4, 128, 'Blue', 179.01)
#
# Sample rows from Brands:
# (1, 'Realme')
# (2, 'Samsung')
# (3, 'Motorola')
#
#
# Join result:
# (1, 'Realme C55 8/256GB Sunshower Libre', 'C55', 8, 256, 'Yellow', 231.6, 'Realme')
# (2, 'Samsung Galaxy M23 5G 4/128GB Azul Libre', 'Galaxy M23', 4, 128, 'Blue', 279.0, 'Realme')
# (3, 'Motorola Moto G13 4/128GB Azul Lavanda Libre', 'Moto G13', 4, 128, 'Blue', 179.01, 'Realme')
# (4, 'Xiaomi Redmi Note 11S 6/128GB Gris Libre', 'Redmi Note 11S', 6, 128, 'Gray', 279.99, 'Realme')
# (5, 'Nothing Phone (2) 12/512GB Blanco Libre', 'Phone (2)', 12, 512, 'White', 799.0, 'Realme')
# (6, 'Motorola Moto E32s 4/64GB Gris Libre', 'Moto E32s', 4, 64, 'Gray', 148.52, 'Realme')
# (7, 'Nothing Phone (2) 12/256GB Blanco Libre', 'Phone (2)', 12, 256, 'White', 699.0, 'Realme')
# (8, 'Realme 9 Pro 5G 8/128GB Negro Libre', '9 Pro', 8, 128, 'Black', 352.59, 'Realme')
# (9, 'Samsung Galaxy M23 5G 4/128GB Verde Libre', 'Galaxy M23', 4, 128, 'Green', 279.0, 'Realme')
# (10, 'Xiaomi Redmi Note 12 Pro 8/256GB Gris Grafito Libre', 'Redmi Note 12', 8, 256, 'Gray', 329.99, 'Realme')
# (11, 'POCO M4 5G 6/128GB Negro Libre', 'M4', 6, 128, 'Black', 219.99, 'Realme')
# (12, 'Realme C31 4/64GB Plata Libre', 'C31', 4, 64, 'Silver', 172.59, 'Realme')
# (13, 'Realme C55 8/256GB Rainy Night Libre', 'C55', 8, 256, 'Black', 231.6, 'Realme')
# (14, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Negro Libre', 'Redmi Note 12', 8, 256, 'Black', 382.99, 'Realme')
# (15, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Azul Libre', 'Redmi Note 12', 8, 256, 'Blue', 399.91, 'Realme')
# (16, 'Xiaomi Redmi Note 12 4/128GB Gris Libre', 'Redmi Note 12', 4, 128, 'Gray', 249.99, 'Realme')
# (17, 'Apple iPhone 14 128GB Medianoche Libre', 'iPhone 14', None, 128, 'Black', 1009.0, 'Realme')
# (18, 'Xiaomi Redmi Note 12 Pro 8/256GB Azul Glaciar Libre', 'Redmi Note 12', 8, 256, 'Blue', 249.26, 'Realme')
# (19, 'Samsung Galaxy M13 4/64GB Verde Libre', 'Galaxy M13', 4, 64, 'Green', 179.0, 'Realme')
# (20, 'Xiaomi Redmi 10C 4/64GB Gris Libre', 'Redmi 10C', 4, 64, 'Gray', 179.99, 'Realme')
# (21, 'Realme Narzo 50i Prime 3/32GB Azul Libre', 'Narzo 50i', 3, 32, 'Blue', 141.6, 'Realme')
# (22, 'Realme 11 Pro 5G 8/256GB Amoled FHD+ Curved Sunrise Beige Libre', '11 Pro', 8, 256, 'White', 401.6, 'Realme')
# (23, 'POCO X5 Pro 5G 8/256GB Negro Libre + Cable USB-C a Jack', 'X5 Pro', 8, 256, 'Black', 392.6, 'Realme')
# (1, 'Realme C55 8/256GB Sunshower Libre', 'C55', 8, 256, 'Yellow', 231.6, 'Samsung')
# (2, 'Samsung Galaxy M23 5G 4/128GB Azul Libre', 'Galaxy M23', 4, 128, 'Blue', 279.0, 'Samsung')
# (3, 'Motorola Moto G13 4/128GB Azul Lavanda Libre', 'Moto G13', 4, 128, 'Blue', 179.01, 'Samsung')
# (4, 'Xiaomi Redmi Note 11S 6/128GB Gris Libre', 'Redmi Note 11S', 6, 128, 'Gray', 279.99, 'Samsung')
# (5, 'Nothing Phone (2) 12/512GB Blanco Libre', 'Phone (2)', 12, 512, 'White', 799.0, 'Samsung')
# (6, 'Motorola Moto E32s 4/64GB Gris Libre', 'Moto E32s', 4, 64, 'Gray', 148.52, 'Samsung')
# (7, 'Nothing Phone (2) 12/256GB Blanco Libre', 'Phone (2)', 12, 256, 'White', 699.0, 'Samsung')
# (8, 'Realme 9 Pro 5G 8/128GB Negro Libre', '9 Pro', 8, 128, 'Black', 352.59, 'Samsung')
# (9, 'Samsung Galaxy M23 5G 4/128GB Verde Libre', 'Galaxy M23', 4, 128, 'Green', 279.0, 'Samsung')
# (10, 'Xiaomi Redmi Note 12 Pro 8/256GB Gris Grafito Libre', 'Redmi Note 12', 8, 256, 'Gray', 329.99, 'Samsung')
# (11, 'POCO M4 5G 6/128GB Negro Libre', 'M4', 6, 128, 'Black', 219.99, 'Samsung')
# (12, 'Realme C31 4/64GB Plata Libre', 'C31', 4, 64, 'Silver', 172.59, 'Samsung')
# (13, 'Realme C55 8/256GB Rainy Night Libre', 'C55', 8, 256, 'Black', 231.6, 'Samsung')
# (14, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Negro Libre', 'Redmi Note 12', 8, 256, 'Black', 382.99, 'Samsung')
# (15, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Azul Libre', 'Redmi Note 12', 8, 256, 'Blue', 399.91, 'Samsung')
# (16, 'Xiaomi Redmi Note 12 4/128GB Gris Libre', 'Redmi Note 12', 4, 128, 'Gray', 249.99, 'Samsung')
# (17, 'Apple iPhone 14 128GB Medianoche Libre', 'iPhone 14', None, 128, 'Black', 1009.0, 'Samsung')
# (18, 'Xiaomi Redmi Note 12 Pro 8/256GB Azul Glaciar Libre', 'Redmi Note 12', 8, 256, 'Blue', 249.26, 'Samsung')
# (19, 'Samsung Galaxy M13 4/64GB Verde Libre', 'Galaxy M13', 4, 64, 'Green', 179.0, 'Samsung')
# (20, 'Xiaomi Redmi 10C 4/64GB Gris Libre', 'Redmi 10C', 4, 64, 'Gray', 179.99, 'Samsung')
# (21, 'Realme Narzo 50i Prime 3/32GB Azul Libre', 'Narzo 50i', 3, 32, 'Blue', 141.6, 'Samsung')
# (22, 'Realme 11 Pro 5G 8/256GB Amoled FHD+ Curved Sunrise Beige Libre', '11 Pro', 8, 256, 'White', 401.6, 'Samsung')
# (23, 'POCO X5 Pro 5G 8/256GB Negro Libre + Cable USB-C a Jack', 'X5 Pro', 8, 256, 'Black', 392.6, 'Samsung')
# (1, 'Realme C55 8/256GB Sunshower Libre', 'C55', 8, 256, 'Yellow', 231.6, 'Motorola')
# (2, 'Samsung Galaxy M23 5G 4/128GB Azul Libre', 'Galaxy M23', 4, 128, 'Blue', 279.0, 'Motorola')
# (3, 'Motorola Moto G13 4/128GB Azul Lavanda Libre', 'Moto G13', 4, 128, 'Blue', 179.01, 'Motorola')
# (4, 'Xiaomi Redmi Note 11S 6/128GB Gris Libre', 'Redmi Note 11S', 6, 128, 'Gray', 279.99, 'Motorola')
# (5, 'Nothing Phone (2) 12/512GB Blanco Libre', 'Phone (2)', 12, 512, 'White', 799.0, 'Motorola')
# (6, 'Motorola Moto E32s 4/64GB Gris Libre', 'Moto E32s', 4, 64, 'Gray', 148.52, 'Motorola')
# (7, 'Nothing Phone (2) 12/256GB Blanco Libre', 'Phone (2)', 12, 256, 'White', 699.0, 'Motorola')
# (8, 'Realme 9 Pro 5G 8/128GB Negro Libre', '9 Pro', 8, 128, 'Black', 352.59, 'Motorola')
# (9, 'Samsung Galaxy M23 5G 4/128GB Verde Libre', 'Galaxy M23', 4, 128, 'Green', 279.0, 'Motorola')
# (10, 'Xiaomi Redmi Note 12 Pro 8/256GB Gris Grafito Libre', 'Redmi Note 12', 8, 256, 'Gray', 329.99, 'Motorola')
# (11, 'POCO M4 5G 6/128GB Negro Libre', 'M4', 6, 128, 'Black', 219.99, 'Motorola')
# (12, 'Realme C31 4/64GB Plata Libre', 'C31', 4, 64, 'Silver', 172.59, 'Motorola')
# (13, 'Realme C55 8/256GB Rainy Night Libre', 'C55', 8, 256, 'Black', 231.6, 'Motorola')
# (14, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Negro Libre', 'Redmi Note 12', 8, 256, 'Black', 382.99, 'Motorola')
# (15, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Azul Libre', 'Redmi Note 12', 8, 256, 'Blue', 399.91, 'Motorola')
# (16, 'Xiaomi Redmi Note 12 4/128GB Gris Libre', 'Redmi Note 12', 4, 128, 'Gray', 249.99, 'Motorola')
# (17, 'Apple iPhone 14 128GB Medianoche Libre', 'iPhone 14', None, 128, 'Black', 1009.0, 'Motorola')
# (18, 'Xiaomi Redmi Note 12 Pro 8/256GB Azul Glaciar Libre', 'Redmi Note 12', 8, 256, 'Blue', 249.26, 'Motorola')
# (19, 'Samsung Galaxy M13 4/64GB Verde Libre', 'Galaxy M13', 4, 64, 'Green', 179.0, 'Motorola')
# (20, 'Xiaomi Redmi 10C 4/64GB Gris Libre', 'Redmi 10C', 4, 64, 'Gray', 179.99, 'Motorola')
# (21, 'Realme Narzo 50i Prime 3/32GB Azul Libre', 'Narzo 50i', 3, 32, 'Blue', 141.6, 'Motorola')
# (22, 'Realme 11 Pro 5G 8/256GB Amoled FHD+ Curved Sunrise Beige Libre', '11 Pro', 8, 256, 'White', 401.6, 'Motorola')
# (23, 'POCO X5 Pro 5G 8/256GB Negro Libre + Cable USB-C a Jack', 'X5 Pro', 8, 256, 'Black', 392.6, 'Motorola')
# (1, 'Realme C55 8/256GB Sunshower Libre', 'C55', 8, 256, 'Yellow', 231.6, 'Xiaomi')
# (2, 'Samsung Galaxy M23 5G 4/128GB Azul Libre', 'Galaxy M23', 4, 128, 'Blue', 279.0, 'Xiaomi')
# (3, 'Motorola Moto G13 4/128GB Azul Lavanda Libre', 'Moto G13', 4, 128, 'Blue', 179.01, 'Xiaomi')
# (4, 'Xiaomi Redmi Note 11S 6/128GB Gris Libre', 'Redmi Note 11S', 6, 128, 'Gray', 279.99, 'Xiaomi')
# (5, 'Nothing Phone (2) 12/512GB Blanco Libre', 'Phone (2)', 12, 512, 'White', 799.0, 'Xiaomi')
# (6, 'Motorola Moto E32s 4/64GB Gris Libre', 'Moto E32s', 4, 64, 'Gray', 148.52, 'Xiaomi')
# (7, 'Nothing Phone (2) 12/256GB Blanco Libre', 'Phone (2)', 12, 256, 'White', 699.0, 'Xiaomi')
# (8, 'Realme 9 Pro 5G 8/128GB Negro Libre', '9 Pro', 8, 128, 'Black', 352.59, 'Xiaomi')
# (9, 'Samsung Galaxy M23 5G 4/128GB Verde Libre', 'Galaxy M23', 4, 128, 'Green', 279.0, 'Xiaomi')
# (10, 'Xiaomi Redmi Note 12 Pro 8/256GB Gris Grafito Libre', 'Redmi Note 12', 8, 256, 'Gray', 329.99, 'Xiaomi')
# (11, 'POCO M4 5G 6/128GB Negro Libre', 'M4', 6, 128, 'Black', 219.99, 'Xiaomi')
# (12, 'Realme C31 4/64GB Plata Libre', 'C31', 4, 64, 'Silver', 172.59, 'Xiaomi')
# (13, 'Realme C55 8/256GB Rainy Night Libre', 'C55', 8, 256, 'Black', 231.6, 'Xiaomi')
# (14, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Negro Libre', 'Redmi Note 12', 8, 256, 'Black', 382.99, 'Xiaomi')
# (15, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Azul Libre', 'Redmi Note 12', 8, 256, 'Blue', 399.91, 'Xiaomi')
# (16, 'Xiaomi Redmi Note 12 4/128GB Gris Libre', 'Redmi Note 12', 4, 128, 'Gray', 249.99, 'Xiaomi')
# (17, 'Apple iPhone 14 128GB Medianoche Libre', 'iPhone 14', None, 128, 'Black', 1009.0, 'Xiaomi')
# (18, 'Xiaomi Redmi Note 12 Pro 8/256GB Azul Glaciar Libre', 'Redmi Note 12', 8, 256, 'Blue', 249.26, 'Xiaomi')
# (19, 'Samsung Galaxy M13 4/64GB Verde Libre', 'Galaxy M13', 4, 64, 'Green', 179.0, 'Xiaomi')
# (20, 'Xiaomi Redmi 10C 4/64GB Gris Libre', 'Redmi 10C', 4, 64, 'Gray', 179.99, 'Xiaomi')
# (21, 'Realme Narzo 50i Prime 3/32GB Azul Libre', 'Narzo 50i', 3, 32, 'Blue', 141.6, 'Xiaomi')
# (22, 'Realme 11 Pro 5G 8/256GB Amoled FHD+ Curved Sunrise Beige Libre', '11 Pro', 8, 256, 'White', 401.6, 'Xiaomi')
# (23, 'POCO X5 Pro 5G 8/256GB Negro Libre + Cable USB-C a Jack', 'X5 Pro', 8, 256, 'Black', 392.6, 'Xiaomi')
# (1, 'Realme C55 8/256GB Sunshower Libre', 'C55', 8, 256, 'Yellow', 231.6, 'Nothing')
# (2, 'Samsung Galaxy M23 5G 4/128GB Azul Libre', 'Galaxy M23', 4, 128, 'Blue', 279.0, 'Nothing')
# (3, 'Motorola Moto G13 4/128GB Azul Lavanda Libre', 'Moto G13', 4, 128, 'Blue', 179.01, 'Nothing')
# (4, 'Xiaomi Redmi Note 11S 6/128GB Gris Libre', 'Redmi Note 11S', 6, 128, 'Gray', 279.99, 'Nothing')
# (5, 'Nothing Phone (2) 12/512GB Blanco Libre', 'Phone (2)', 12, 512, 'White', 799.0, 'Nothing')
# (6, 'Motorola Moto E32s 4/64GB Gris Libre', 'Moto E32s', 4, 64, 'Gray', 148.52, 'Nothing')
# (7, 'Nothing Phone (2) 12/256GB Blanco Libre', 'Phone (2)', 12, 256, 'White', 699.0, 'Nothing')
# (8, 'Realme 9 Pro 5G 8/128GB Negro Libre', '9 Pro', 8, 128, 'Black', 352.59, 'Nothing')
# (9, 'Samsung Galaxy M23 5G 4/128GB Verde Libre', 'Galaxy M23', 4, 128, 'Green', 279.0, 'Nothing')
# (10, 'Xiaomi Redmi Note 12 Pro 8/256GB Gris Grafito Libre', 'Redmi Note 12', 8, 256, 'Gray', 329.99, 'Nothing')
# (11, 'POCO M4 5G 6/128GB Negro Libre', 'M4', 6, 128, 'Black', 219.99, 'Nothing')
# (12, 'Realme C31 4/64GB Plata Libre', 'C31', 4, 64, 'Silver', 172.59, 'Nothing')
# (13, 'Realme C55 8/256GB Rainy Night Libre', 'C55', 8, 256, 'Black', 231.6, 'Nothing')
# (14, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Negro Libre', 'Redmi Note 12', 8, 256, 'Black', 382.99, 'Nothing')
# (15, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Azul Libre', 'Redmi Note 12', 8, 256, 'Blue', 399.91, 'Nothing')
# (16, 'Xiaomi Redmi Note 12 4/128GB Gris Libre', 'Redmi Note 12', 4, 128, 'Gray', 249.99, 'Nothing')
# (17, 'Apple iPhone 14 128GB Medianoche Libre', 'iPhone 14', None, 128, 'Black', 1009.0, 'Nothing')
# (18, 'Xiaomi Redmi Note 12 Pro 8/256GB Azul Glaciar Libre', 'Redmi Note 12', 8, 256, 'Blue', 249.26, 'Nothing')
# (19, 'Samsung Galaxy M13 4/64GB Verde Libre', 'Galaxy M13', 4, 64, 'Green', 179.0, 'Nothing')
# (20, 'Xiaomi Redmi 10C 4/64GB Gris Libre', 'Redmi 10C', 4, 64, 'Gray', 179.99, 'Nothing')
# (21, 'Realme Narzo 50i Prime 3/32GB Azul Libre', 'Narzo 50i', 3, 32, 'Blue', 141.6, 'Nothing')
# (22, 'Realme 11 Pro 5G 8/256GB Amoled FHD+ Curved Sunrise Beige Libre', '11 Pro', 8, 256, 'White', 401.6, 'Nothing')
# (23, 'POCO X5 Pro 5G 8/256GB Negro Libre + Cable USB-C a Jack', 'X5 Pro', 8, 256, 'Black', 392.6, 'Nothing')
# (1, 'Realme C55 8/256GB Sunshower Libre', 'C55', 8, 256, 'Yellow', 231.6, 'POCO')
# (2, 'Samsung Galaxy M23 5G 4/128GB Azul Libre', 'Galaxy M23', 4, 128, 'Blue', 279.0, 'POCO')
# (3, 'Motorola Moto G13 4/128GB Azul Lavanda Libre', 'Moto G13', 4, 128, 'Blue', 179.01, 'POCO')
# (4, 'Xiaomi Redmi Note 11S 6/128GB Gris Libre', 'Redmi Note 11S', 6, 128, 'Gray', 279.99, 'POCO')
# (5, 'Nothing Phone (2) 12/512GB Blanco Libre', 'Phone (2)', 12, 512, 'White', 799.0, 'POCO')
# (6, 'Motorola Moto E32s 4/64GB Gris Libre', 'Moto E32s', 4, 64, 'Gray', 148.52, 'POCO')
# (7, 'Nothing Phone (2) 12/256GB Blanco Libre', 'Phone (2)', 12, 256, 'White', 699.0, 'POCO')
# (8, 'Realme 9 Pro 5G 8/128GB Negro Libre', '9 Pro', 8, 128, 'Black', 352.59, 'POCO')
# (9, 'Samsung Galaxy M23 5G 4/128GB Verde Libre', 'Galaxy M23', 4, 128, 'Green', 279.0, 'POCO')
# (10, 'Xiaomi Redmi Note 12 Pro 8/256GB Gris Grafito Libre', 'Redmi Note 12', 8, 256, 'Gray', 329.99, 'POCO')
# (11, 'POCO M4 5G 6/128GB Negro Libre', 'M4', 6, 128, 'Black', 219.99, 'POCO')
# (12, 'Realme C31 4/64GB Plata Libre', 'C31', 4, 64, 'Silver', 172.59, 'POCO')
# (13, 'Realme C55 8/256GB Rainy Night Libre', 'C55', 8, 256, 'Black', 231.6, 'POCO')
# (14, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Negro Libre', 'Redmi Note 12', 8, 256, 'Black', 382.99, 'POCO')
# (15, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Azul Libre', 'Redmi Note 12', 8, 256, 'Blue', 399.91, 'POCO')
# (16, 'Xiaomi Redmi Note 12 4/128GB Gris Libre', 'Redmi Note 12', 4, 128, 'Gray', 249.99, 'POCO')
# (17, 'Apple iPhone 14 128GB Medianoche Libre', 'iPhone 14', None, 128, 'Black', 1009.0, 'POCO')
# (18, 'Xiaomi Redmi Note 12 Pro 8/256GB Azul Glaciar Libre', 'Redmi Note 12', 8, 256, 'Blue', 249.26, 'POCO')
# (19, 'Samsung Galaxy M13 4/64GB Verde Libre', 'Galaxy M13', 4, 64, 'Green', 179.0, 'POCO')
# (20, 'Xiaomi Redmi 10C 4/64GB Gris Libre', 'Redmi 10C', 4, 64, 'Gray', 179.99, 'POCO')
# (21, 'Realme Narzo 50i Prime 3/32GB Azul Libre', 'Narzo 50i', 3, 32, 'Blue', 141.6, 'POCO')
# (22, 'Realme 11 Pro 5G 8/256GB Amoled FHD+ Curved Sunrise Beige Libre', '11 Pro', 8, 256, 'White', 401.6, 'POCO')
# (23, 'POCO X5 Pro 5G 8/256GB Negro Libre + Cable USB-C a Jack', 'X5 Pro', 8, 256, 'Black', 392.6, 'POCO')
# (1, 'Realme C55 8/256GB Sunshower Libre', 'C55', 8, 256, 'Yellow', 231.6, 'Apple')
# (2, 'Samsung Galaxy M23 5G 4/128GB Azul Libre', 'Galaxy M23', 4, 128, 'Blue', 279.0, 'Apple')
# (3, 'Motorola Moto G13 4/128GB Azul Lavanda Libre', 'Moto G13', 4, 128, 'Blue', 179.01, 'Apple')
# (4, 'Xiaomi Redmi Note 11S 6/128GB Gris Libre', 'Redmi Note 11S', 6, 128, 'Gray', 279.99, 'Apple')
# (5, 'Nothing Phone (2) 12/512GB Blanco Libre', 'Phone (2)', 12, 512, 'White', 799.0, 'Apple')
# (6, 'Motorola Moto E32s 4/64GB Gris Libre', 'Moto E32s', 4, 64, 'Gray', 148.52, 'Apple')
# (7, 'Nothing Phone (2) 12/256GB Blanco Libre', 'Phone (2)', 12, 256, 'White', 699.0, 'Apple')
# (8, 'Realme 9 Pro 5G 8/128GB Negro Libre', '9 Pro', 8, 128, 'Black', 352.59, 'Apple')
# (9, 'Samsung Galaxy M23 5G 4/128GB Verde Libre', 'Galaxy M23', 4, 128, 'Green', 279.0, 'Apple')
# (10, 'Xiaomi Redmi Note 12 Pro 8/256GB Gris Grafito Libre', 'Redmi Note 12', 8, 256, 'Gray', 329.99, 'Apple')
# (11, 'POCO M4 5G 6/128GB Negro Libre', 'M4', 6, 128, 'Black', 219.99, 'Apple')
# (12, 'Realme C31 4/64GB Plata Libre', 'C31', 4, 64, 'Silver', 172.59, 'Apple')
# (13, 'Realme C55 8/256GB Rainy Night Libre', 'C55', 8, 256, 'Black', 231.6, 'Apple')
# (14, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Negro Libre', 'Redmi Note 12', 8, 256, 'Black', 382.99, 'Apple')
# (15, 'Xiaomi Redmi Note 12 Pro 5G 8/256GB Azul Libre', 'Redmi Note 12', 8, 256, 'Blue', 399.91, 'Apple')
# (16, 'Xiaomi Redmi Note 12 4/128GB Gris Libre', 'Redmi Note 12', 4, 128, 'Gray', 249.99, 'Apple')
# (17, 'Apple iPhone 14 128GB Medianoche Libre', 'iPhone 14', None, 128, 'Black', 1009.0, 'Apple')
# (18, 'Xiaomi Redmi Note 12 Pro 8/256GB Azul Glaciar Libre', 'Redmi Note 12', 8, 256, 'Blue', 249.26, 'Apple')
# (19, 'Samsung Galaxy M13 4/64GB Verde Libre', 'Galaxy M13', 4, 64, 'Green', 179.0, 'Apple')
# (20, 'Xiaomi Redmi 10C 4/64GB Gris Libre', 'Redmi 10C', 4, 64, 'Gray', 179.99, 'Apple')
# (21, 'Realme Narzo 50i Prime 3/32GB Azul Libre', 'Narzo 50i', 3, 32, 'Blue', 141.6, 'Apple')
# (22, 'Realme 11 Pro 5G 8/256GB Amoled FHD+ Curved Sunrise Beige Libre', '11 Pro', 8, 256, 'White', 401.6, 'Apple')
# (23, 'POCO X5 Pro 5G 8/256GB Negro Libre + Cable USB-C a Jack', 'X5 Pro', 8, 256, 'Black', 392.6, 'Apple')
